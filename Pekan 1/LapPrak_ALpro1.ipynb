# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma dan Pemograman**
#
# **“PENGENALAN PYTHON, VSCODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Muhammad Farras Agustin**
#
# **2611533013**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum “Pengenalan Python, VS Code, dan Koneksi ke GitHub” dengan baik. Laporan ini disusun sebagai dokumentasi dan refleksi atas praktikum yang telah dilaksanakan pada pertemuan minggu ke-1 untuk mata kuliah Praktikum Algoritma Pemrograman. Praktikum ini berfokus pada pengenalan bahasa pemrograman Python, penggunaan Visual Studio Code (VS Code) sebagai code editor, serta pengenalan koneksi dan pengelolaan kode program menggunakan GitHub.
#
# Melalui praktikum ini, output yang diharapkan adalah penulis dapat memahami konsep-konsep dasar pemrograman Python serta penggunaan VS Code dalam membuat dan menjalankan program. Dalam praktikum ini, penulis juga mempelajari cara menghubungkan proyek dengan GitHub untuk menyimpan, mengelola, dan membagikan kode program secara daring. Dengan adanya praktikum ini, penulis diharapkan dapat menerapkan pengetahuan yang diperoleh dalam pembuatan proyek-proyek sederhana serta memahami dasar penggunaan GitHub dalam proses pengembangan program.
#
#
#                                                                          Padang, 2026
#
#
#
#                                                                     Muhammad Farras Agustin
#                                                                                  2611533013

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi membuat kemampuan pemrograman menjadi salah satu keterampilan yang penting untuk dipelajari. Salah satu bahasa pemrograman yang banyak digunakan adalah Python. Python memiliki sintaks yang sederhana dan mudah dipahami sehingga cocok digunakan untuk mempelajari dasar-dasar pemrograman. Selain itu, Python dapat digunakan dalam berbagai bidang, seperti pengembangan perangkat lunak, pengolahan data, kecerdasan buatan, dan otomatisasi.
# Dalam proses pembuatan program, diperlukan perangkat lunak yang dapat membantu programmer menulis, mengelola, dan menjalankan kode. Visual Studio Code (VS Code) merupakan salah satu code editor yang dapat digunakan untuk mengembangkan program Python. VS Code menyediakan berbagai fitur yang mendukung kegiatan pemrograman, seperti syntax highlighting, terminal, debugging, dan ekstensi.
# Selain bahasa pemrograman dan code editor, pengelolaan kode juga menjadi bagian penting dalam pengembangan perangkat lunak. GitHub merupakan platform yang dapat digunakan untuk menyimpan dan mengelola proyek pemrograman secara daring. GitHub juga mendukung penggunaan sistem kontrol versi sehingga perubahan pada kode dapat dicatat dan dikelola dengan lebih terstruktur. Penggunaan Python, VS Code, dan GitHub secara bersama-sama dapat membantu proses pembelajaran serta pengembangan program menjadi lebih efektif dan terorganisir.
# Oleh karena itu, praktikum pengenalan Python, VS Code, dan GitHub penting dilakukan agar mahasiswa memahami dasar penggunaan ketiga teknologi tersebut serta mampu menggunakannya dalam proses pembuatan dan pengelolaan program..
#
# ## 1.2 Tujuan
# 1.Memahami dasar-dasar bahasa pemrograman Python.
#
# 2.Mengetahui fungsi dan penggunaan Visual Studio Code sebagai code editor.
#
# 3.Memahami fungsi GitHub dalam menyimpan, mengelola, dan melakukan kontrol versi terhadap proyek pemrograman.
#
# ## 1.3 Manfaat
# 1.Meningkatkan pemahaman dan keterampilan dasar dalam menggunakan bahasa pemrograman Python.
#
# 2.Membantu mahasiswa memahami dan menggunakan Visual Studio Code sebagai lingkungan untuk menulis dan menjalankan program.
#
# 3.Meningkatkan kemampuan dalam menggunakan GitHub untuk menyimpan, mengelola, dan berbagi proyek pemrograman.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1.Python
#
# Python merupakan bahasa pemrograman yang memiliki sintaks sederhana dan mudah dipelajari. Python dapat digunakan untuk berbagai kebutuhan, seperti pembuatan aplikasi, pengolahan data, otomatisasi, dan pengembangan perangkat lunak. Python juga menyediakan berbagai struktur data dan fitur pemrograman yang mendukung pembuatan program secara efisien.
#
# 2.Visual Studio Code
#
# Visual Studio Code atau VS Code adalah code editor yang dapat digunakan untuk menulis dan mengembangkan program. Untuk pemrograman Python, VS Code dapat menggunakan ekstensi Python yang menyediakan fitur seperti IntelliSense, autocomplete, debugging, testing, dan menjalankan kode Python. VS Code berfungsi sebagai tempat untuk menulis dan mengelola kode, sedangkan Python interpreter digunakan untuk menjalankan program tersebut
#
# 3.GitHub
#
# GitHub merupakan platform untuk menyimpan dan mengelola proyek pemrograman menggunakan sistem kontrol versi Git. Git dapat mencatat perubahan yang dilakukan pada kode sehingga riwayat perubahan dapat diketahui dan versi sebelumnya dapat dipulihkan jika diperlukan. GitHub juga mendukung kolaborasi melalui repository, branch, commit, dan pull request

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program C_2611533013
#
# Program Python dibuat menggunakan Visual Studio Code. Pada praktikum ini, Python digunakan untuk membuat dan menjalankan program sederhana sebagai pengenalan terhadap sintaks dasar bahasa Python.

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro 
"""
print("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas") 
print("/ \\ // \\\\ /// \\\\\\")   
print("program ini" + "dibuat oleh" 
 + "Muhammad Farras Agustin_2611533013")
# Out:
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program inidibuat olehMuhammad Farras Agustin_2611533013

# %% [markdown]
# Hello World
#
# Program ini menghasilkan
#
# Empat baris output
#
# / \ // \\ /// \\
#
# Program ini dibuat oleh /n Muhammad Farras Agustin dan 2611533013

# %% [markdown]
# penjelasan:
#
# 1. '#' digunakan sebagai simbol untuk command dalam bahasa python.
#
# 2. """ dogunakan untuk menyimpan string yang lebih dari satu baris code.
#
# 3. print() digunakan untuk menampilkan data ke layar.
#
# 4. Program dapat dijalankan melalui terminal atau fitur Run pada VS Code.

# %% [markdown]
# ### 2.2.2 Membuat Repository GitHub

# %% [markdown]
# Setelah program dibuat dan diuji pada VS Code, proyek dapat dihubungkan dengan GitHub. Repository digunakan untuk menyimpan kode program secara daring.
#
# Tahapan yang dilakukan yaitu:
#
# 1. Membuat repository baru pada GitHub.
# 2. Membuka folder proyek menggunakan VS Code.
# 3. Membuka terminal pada VS Code.
# 4. Menginisialisasi Git pada folder proyek.
# 5. Menambahkan file ke dalam staging.
# 6. Membuat commit.
# 7. Menghubungkan repository lokal dengan repository GitHub.
# 8. Melakukan push untuk mengunggah kode ke GitHub.
# Contoh perintah yang digunakan:

# %%
git init
git add .
git commit -m "Initial commit"
git branch -M main
git remote add origin https://github.com/username/nama-repository.git
git push -u origin main

# %% [markdown]
# Penjelasan:
#
# 1. git init digunakan untuk membuat repository Git pada folder proyek.
#
# 2. git add . digunakan untuk menambahkan seluruh perubahan ke staging area.
#
# 3. git commit digunakan untuk menyimpan perubahan dengan sebuah pesan.
# git branch -M main digunakan untuk menentukan branch utama dengan nama main.
#
# 4. git remote add origin digunakan untuk menghubungkan repository lokal dengan repository GitHub.
#
# 5. git push digunakan untuk mengunggah kode dari komputer ke GitHub.

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "C_2611533013"

# %%
print("      _____________")
print("     /             \\")
print(" ___/_______________\\___")
print("|                     _  |")
print("|    ___         ___ | | |")
print("|___|   |_______|   ||_|_|")
print("    |___|       |___|")
# Out:
#       _____________
#      /             \
#  ___/_______________\___
# |                     _  |
# |    ___         ___ | | |
# |___|   |_______|   ||_|_|
#     |___|       |___|

# %% [markdown]
# **Penjelasan :** Program ini hanya melakukan operasi print() dengan tujuan menciptakan desain visual mobil.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python, Visual Studio Code (VS Code), dan GitHub merupakan tools yang saling mendukung dalam proses pemrograman. Python digunakan sebagai bahasa pemrograman untuk membuat dan menjalankan program, sedangkan VS Code digunakan sebagai editor untuk menulis, mengedit, serta menjalankan kode Python dengan lebih mudah.
# Dalam pengembangan program, GitHub digunakan untuk menyimpan, mengelola, dan membagikan kode secara daring serta membantu dalam pengelolaan versi program. Dengan memahami penggunaan Python, VS Code, dan GitHub, proses pembuatan, pengujian, hingga penyimpanan dan pengelolaan program dapat dilakukan dengan lebih terstruktur, efisien, dan mudah dikembangkan

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1. Python Software Foundation. (2026). The Python Tutorial. Python Documentation. https://docs.python.org/3/tutorial/
#
# 2. Microsoft. (2026). Python in Visual Studio Code. Visual Studio Code Documentation. https://code.visualstudio.com/docs/languages/python
#
# 3. GitHub. (2026). About repositories. GitHub Docs. https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories
#
# 4. GitHub. (2026). About remote repositories. GitHub Docs. https://docs.github.com/en/get-started/git-basics/about-remote-repositories
