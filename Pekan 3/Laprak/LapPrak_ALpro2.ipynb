# %% [markdown]
# <div align="center">
#
# **LAPORAN PRATIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“OPERATOR PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Muhammad Farras Agustin**
#
# **2611533013**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji dan syukur penulis panjatkan kehadirat Tuhan Yang Maha Esa atas rahmat dan karunia-Nya, sehingga laporan praktikum Algoritma dan Pemrograman Pekan 3 yang membahas tentang "Operator Pada Python" ini dapat diselesaikan dengan baik dan tepat waktu.
# Laporan ini disusun sebagai bentuk dokumentasi dan evaluasi terhadap latihan serta tugas praktikum yang telah dilaksanakan. Penulis mengucapkan terima kasih kepada Dosen Pengampu dan Asisten Laboratorium atas bimbingan serta petunjuk yang diberikan selama proses praktikum berlangsung.
#
# Penulis menyadari bahwa dalam penyusunan laporan ini masih terdapat kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi penyempurnaan laporan di masa mendatang. Semoga laporan ini dapat memberikan manfaat serta menambah wawasan bagi para pembaca.
#
#
#                                                                                                              Padang, 2026
#
#
#
#
#
#                                                                                                     Muhammad Farras Agustin

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman tidak lepas dari proses manipulasi data, kalkulasi matematika, serta evaluasi kondisi logika. Dalam bahasa pemrograman Python, seluruh operasi tersebut diakomodasi melalui operator. Operator merupakan simbol atau kata kunci khusus yang digunakan untuk melakukan operasi pada satu atau lebih nilai (operan).
#
# Pada Pekan 3 ini, praktikum difokuskan untuk memahami dan mengimplementasikan berbagai jenis operator dasar hingga lanjutan dalam Python, yaitu operator aritmatika, perbandingan, logika, assignment, operator keanggotaan (membership) & identitas (identity), serta operator tingkat bit (bitwise). Pemahaman yang mendalam mengenai karakteristik dan cara kerja masing-masing operator sangat penting untuk membangun struktur logika program yang efisien, benar, dan bebas dari kesalahan runtime.
#
# ## 1.2 Tujuan
# 1. Memahami jenis-jenis operator yang tersedia dalam bahasa pemrograman Python.
#
# 2. Mampu menerapkan operator aritmatika, perbandingan, dan logika dalam penyelesaian masalah komputasi dasar.
#
# 3. Memahami penggunaan operator assignment untuk menyederhanakan penulisan ekspresi pemrograman.
#
# 4. Memahami konsep dan penerapan operator keanggotaan (in, not in) serta operator identitas (is, is not).
# 5. Memahami manipulasi data pada tingkat biner menggunakan operator bitwise beserta pembacaan hasilnya.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat menuliskan ekspresi logika dan matematika dengan sintaksis yang benar pada Python.
#
# 2. Mahasiswa mampu menganalisis alur eksekusi program yang melibatkan berbagai kombinasi operator.
#
# 3. Mahasiswa memiliki landasan yang kuat untuk membangun struktur kontrol keputusan (conditional) dan perulangan (looping) pada praktikum pekan-pekan berikutnya.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. Operator Aritmatika: Simbol matematika yang digunakan untuk melakukan operasi hitung dasar, seperti penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), sisa bagi/modulus (%), dan perpangkatan (**).
#
# 2. Operator Perbandingan (Relasional): Operator yang membandingkan dua nilai dan menghasilkan nilai boolean (True atau False). Meliputi lebih besar (>), lebih kecil (<), lebih besar sama dengan (>=), lebih kecil sama dengan (<=), sama dengan (==), dan tidak sama dengan (!=).
#
# 3. Operator Logika: Digunakan untuk membandingkan dua ekspresi boolean. Terdiri dari and (bernilai True jika keduanya True), or (bernilai True jika salah satu True), dan not (membalikkan nilai boolean).
#
# 4. Operator Assignment (Penugasan): Digunakan untuk memberikan atau menguji nilai ke dalam variabel. Operator gabungan (seperti +=, -=, *=, /=, //=, %=, **=) melakukan operasi matematika sekaligus memperbarui nilai variabel tersebut.
#
# 5. Operator Keanggotaan & Identitas:
#
#      -Keanggotaan (in, not in): Memeriksa apakah suatu nilai ada di dalam sebuah urutan/koleksi data (seperti List atau String).
#
#     -Identitas (is, is not): Membandingkan apakah dua variabel merujuk pada objek/lokasi memori yang sama (berbeda dengan == yang hanya membandingkan nilainya).
#
# 6. Operator Bitwise: Operator yang memanipulasi bit angka secara langsung pada tingkat biner (0 dan 1). Terdiri dari AND (&), OR (|), XOR (^), NOT (~), Left Shift (<<), dan Right Shift (>>).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Aritmatika (Aritmatika_2611533013.py)

# %%
# Buat file dengan nama aritmatika_NIM.py
# Buat program untuk operator aritmatika dalam Python
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menngunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_3013 = int(input("input angka-1: "))
angka2_3013 = int(input("input angka-2: "))

# Penjumlahan
hasil = angka1_3013 + angka2_3013
print("\nOperator Penjumlahan")
print("Hasil =", hasil)  

# Pengurangan
hasil = angka1_3013 - angka2_3013
print("\nOperator Pengurangan")
print("Hasil =", hasil)

# Perkalian
hasil = angka1_3013 * angka2_3013
print("\nOperator Perkalian")
print("Hasil =", hasil)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_3013 != 0:
    hasil = angka1_3013 / angka2_3013
    print("\nOperator Pembagian")
    print("Hasil =", hasil)

    hasil = angka1_3013 // angka2_3013
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil)

    hasil = angka1_3013 % angka2_3013
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil = angka1_3013 ** angka2_3013
print("\nOperator Pangkat")
print("Hasil =", hasil)
# Out:
# Operator Penjumlahan
# Hasil = 4
#
# Operator Pengurangan
# Hasil = 0
#
# Operator Perkalian
# Hasil = 4
#
# Operator Pembagian
# Hasil = 1.0
#
# Operator Pembagian Bulat
# Hasil = 1
#
# Operator Sisa Bagi
# Hasil = 0
#
# Operator Pangkat
# Hasil = 4

# %% [markdown]
# **Penjelasan :**
# 1. Membuat input angka
# angka1_3013 = int(input("Input angka-1: "))
#
# angka2_3013 = int(input("Input angka-2: "))
#
# Program meminta pengguna memasukkan dua angka. Fungsi input() digunakan untuk menerima data, sedangkan int() mengubah data yang dimasukkan menjadi tipe integer.
#
# 2. Operator Penjumlahan
# hasil_3013 = angka1_3013 + angka2_3013
#
# Operator + digunakan untuk menjumlahkan angka1_3013 dengan angka2_3013, kemudian hasilnya disimpan ke variabel hasil_3013.
#
# 3. Operator Pengurangan
# hasil_3013 = angka1_3013 - angka2_3013
#
# Operator - digunakan untuk mengurangi nilai angka1_3013 dengan angka2_3013.
#
# 4. Operator Perkalian
# hasil_3013 = angka1_3013 * angka2_3013
#
# Operator * digunakan untuk mengalikan kedua angka yang telah dimasukkan.
#
# 5. Pengecekan angka kedua
#
# if angka2_3013 != 0:
#
# Program memeriksa apakah angka kedua tidak bernilai 0. Hal ini dilakukan karena pembagian dengan angka 0 tidak diperbolehkan (menyebabkan ZeroDivisionError).
#
# Jika angka2_3013 bernilai 0, program menjalankan bagian else: dan menampilkan:
#
# print("Angka kedua tidak boleh bernilai 0.")
#
# 6. Operator Pembagian
# hasil_3013 = angka1_3013 / angka2_3013
#
# Operator / digunakan untuk melakukan pembagian. Hasil pembagian berupa tipe data float.
#
# 7. Operator Pembagian Bulat
# hasil_3013 = angka1_3013 // angka2_3013
#
# Operator // digunakan untuk melakukan pembagian dan mengambil hasil bilangan bulatnya saja (pembulatan ke bawah), tanpa bagian desimal.
#
# 8. Operator Sisa Bagi
# hasil_3013 = angka1_3013 % angka2_3013
#
# Operator % digunakan untuk mendapatkan sisa dari hasil pembagian antara angka1_3013 dan angka2_3013.
#
# 9. Operator Pangkat
# hasil_3013 = angka1_3013 ** angka2_3013
#
# Operator ** digunakan untuk menghitung pangkat, yaitu angka1_3013 dipangkatkan dengan angka2_3013.

# %% [markdown]
# ### 2.2.2 Program Perbandingan (Perbandingan_2611533013.py)

# %%
# buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit terakhir NIM contoh: nilai_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_3013 = int(input("Input angka-1_3013: "))
angka2_3013 = int(input("Input angka-2_3013: "))

# Lebih besar dari
hasil = angka1_3013 > angka2_3013
print("\nOperator Lebih besar Dari")
print("angka1_3013 > angka2_3013 =", hasil)

# lebih kecil dari
hasil = angka1_3013 < angka2_3013
print("\nOperator Lebih kecil Dari")
print("angka1_3013 < angka2_3013 =", hasil)

# Lebih besar dari atau sama dengan
hasil = angka1_3013 >= angka2_3013
print("\nOperator Lebih besar Dari atau sama dengan")
print("angka1_3013 >= angka2_3013 =", hasil)    

# Lebih kecil dari atau sama dengan
hasil = angka1_3013 <= angka2_3013
print("\nOperator Lebih kecil Dari atau sama dengan")
print("angka1_3013 <= angka2_3013 =", hasil)

# Sama dengan
hasil = angka1_3013 == angka2_3013
print("\nOperator Sama dengan")
print("angka1_3013 == angka2_3013 =", hasil)

# Tidak sama dengan
hasil = angka1_3013 != angka2_3013
print("\nOperator Tidak sama dengan")
print("angka1_3013 != angka2_3013 =", hasil)

# Tambahan: perbandingsn berantai dalam python
hasil = 0 < angka1_3013 < 100
print("\nPerbandingan Berantai")
print("0 < angka1_3013 < 100 =", hasil)

hasil= 0 < angka2_3013 < 100
print("0 < angka2_3013 < 100 =", hasil)
# Out:
# Operator Lebih besar Dari
# angka1_3013 > angka2_3013 = True
#
# Operator Lebih kecil Dari
# angka1_3013 < angka2_3013 = False
#
# Operator Lebih besar Dari atau sama dengan
# angka1_3013 >= angka2_3013 = True
#
# Operator Lebih kecil Dari atau sama dengan
# angka1_3013 <= angka2_3013 = False
#
# Operator Sama dengan
# angka1_3013 == angka2_3013 = False
#
# Operator Tidak sama dengan
# angka1_3013 != angka2_3013 = True
# /nPerbandingan Berantai
# 0 < angka1_3013 < 100 = True
# 0 < angka2_3013 < 100 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. membuat input angka
# angka1_3013 = int(input("Input angka-1: "))
#
# angka2_3013 = int(input("Input angka-2: "))
#
# Program meminta masukan dua nilai integer dari pengguna untuk dibandingkan.
#
# 2. Operator Lebih Besar Dari
# hasil_3013 = angka1_3013 > angka2_3013
#
# Operator > mengecek apakah angka1_3013 lebih besar dari angka2_3013. Mengembalikan nilai boolean True jika benar, dan False jika salah.
#
# 3. Operator Lebih Kecil Dari
# hasil_3013 = angka1_3013 < angka2_3013
#
# Operator < mengecek apakah angka1_3013 lebih kecil dari angka2_3013.
#
# 4. Operator Lebih Besar Sama Dengan
# hasil_3013 = angka1_3013 >= angka2_3013
#
# Operator >= mengecek apakah angka1_3013 bernilai lebih besar dari atau sama dengan angka2_3013.
#
# 5. Operator Lebih Kecil Sama Dengan
# hasil_3013 = angka1_3013 <= angka2_3013
#
# Operator <= mengecek apakah angka1_3013 bernilai lebih kecil dari atau sama dengan angka2_3013.
#
# 6. Operator Sama Dengan
# hasil_3013 = angka1_3013 == angka2_3013
#
# Operator == mengecek apakah nilai angka1_3013 sama persis dengan angka2_3013.
#
# 7. Operator Tidak Sama Dengan
# hasil_3013 = angka1_3013 != angka2_3013
#
# Operator != mengecek apakah nilai angka1_3013 tidak sama dengan angka2_3013.
#
# 8. Perbandingan Berantai
# hasil_3013 = 0 < angka1_3013 < 100
#
# Fitur perbandingan berantai mengecek dua kondisi sekaligus, yaitu apakah angka1_3013 lebih besar dari 0 DAN lebih kecil dari 100.

# %% [markdown]
# ### 2.2.3 Program Logika (Logika_2611533013.py)

# %%
# Memasukkan nilai boolean 
# Input tidak peka terhadap huruf besar dan kecil
a1_3013 = input("Input nilai boolean-1 (True/False): ").strip().lower() == "true"
a2_3013 = input("Input nilai boolean-2 (True/False): ").strip().lower() == "true"

print("\nA1_3013 =", a1_3013)
print("A2_3013 =", a2_3013)   

# Konjungsi bernilai True jika keduanya True
hasil_3013 = a1_3013 and a2_3013
print("\nOperator Konjungsi (AND)")
print("A1_3013 and A2_3013 =", hasil_3013)

# Disjungsi bernilai True jika salah satunya True
hasil_3013 = a1_3013 or a2_3013
print("\nDisjungsi (OR)")
print("A1_3013 or A2_3013 =", hasil_3013)

# Negasi A1_3013: membalik nilai A1_3013
hasil_3013 = not a1_3013
print("\nNegasi A1_3013 (NOT)")
print("not A1_3013 =", hasil_3013)

# Negasi A2_3013: membalik nilai A2_3013
hasil_3013 = not a2_3013
print("\nNegasi A2_3013 (NOT)")
print("not A2_3013 =", hasil_3013)

# XOR: bernilai True jika kedua nilai berbeda
hasil_3013 = a1_3013 != a2_3013
print("\nDisjungsi Eksklusif (XOR)")
print("A1_3013 XOR A2_3013 =", hasil_3013)
# Out:
# A1_3013 = False
# A2_3013 = False
#
# Operator Konjungsi (AND)
# A1_3013 and A2_3013 = False
#
# Disjungsi (OR)
# A1_3013 or A2_3013 = False
#
# Negasi A1_3013 (NOT)
# not A1_3013 = True
#
# Negasi A2_3013 (NOT)
# not A2_3013 = True
#
# Disjungsi Eksklusif (XOR)
# A1_3013 XOR A2_3013 = False

# %% [markdown]
# **Penjelasan :**
#
# 1. Membuat input nilai boolean
# a1_3013 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
#
# a2_3013 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"
#
# Program menerima teks dari pengguna, menghapus spasi tepi dengan .strip(), mengubah huruf menjadi kecil dengan .lower(), lalu membandingkannya dengan "true" sehingga langsung menghasilkan nilai boolean True atau False.
#
# 2. Operator Konjungsi (AND)
# hasil_3013 = a1_3013 and a2_3013
#
# Operator and bernilai True hanya jika a1_3013 dan a2_3013 keduanya bernilai True.
#
# 3. Operator Disjungsi (OR)
# hasil_3013 = a1_3013 or a2_3013
#
# Operator or bernilai True jika salah satu atau kedua nilai input bernilai True.
#
# 4. Operator Negasi (NOT)
# hasil_3013 = not a1_3013
#
# Operator not membalikkan nilai boolean. Jika a1_3013 bernilai True, maka hasilnya menjadi False, dan sebaliknya.
#
# 5. Operator Disjungsi Eksklusif (XOR)
# hasil_3013 = a1_3013 != a2_3013
#
# Operasi XOR dimodelkan dengan != (tidak sama dengan), bernilai True jika nilai a1_3013 dan a2_3013 berbeda satu sama lain.

# %% [markdown]
# ### 2.2.4 Program Assigment (Assigment_2611533013.py)

# %%
# Buat file dengan nama assigment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menngunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assigment dalam Python

angka1_3013 = int(input("input angka-1: ")) 
angka2_3013 = int(input("input angka-2: "))

print("\nNilai awal angka1_3013 =", angka1_3013)
print("Nilai awal angka2_3013 =", angka2_3013)

# Assignment biasa
# hasil = angka1_3013
print("\nAssignment Biasa (=)")
print("Hasil_3013 =", angka1_3013)

# Assignment penambahan
hasil_3013 = angka1_3013
hasil_3013 += angka2_3013
print("\nAssignment Penambahan (+=)")
print("Hasil =", hasil_3013)

# Assignment pengurangan
hasil_3013 = angka1_3013
hasil_3013 -= angka2_3013
print("\nAssignment Pengurangan (-=)")
print("Hasil =", hasil_3013)

# Assignment perkalian
hasil_3013 = angka1_3013
hasil_3013 *= angka2_3013
print("\nAssignment Perkalian (*=)")
print("Hasil =", hasil_3013)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3013 != 0:
    hasil_3013 = angka1_3013
    hasil_3013 /= angka2_3013
    print("\nAssignment Pembagian (/=)")
    print("Hasil =", hasil_3013)
    # Operator Tambahan
    hasil_3013 = angka1_3013
    hasil_3013 //= angka2_3013
    print("\nAssignment Pembagian Bulat (//=)")
    print("Hasil =", hasil_3013)
    hasil_3013 = angka1_3013
    hasil_3013 %= angka2_3013
    print("\nAssignment Sisa Bagi (%=)")
    print("Hasil =", hasil_3013)
else:
    print("Angka kedua tidak boleh bernilai 0.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_3013 = angka1_3013
hasil_3013 **= angka2_3013
print("\nAssignment Perpangkatan (**=)")
print("Hasil =", hasil_3013)
# Out:
# Nilai awal angka1_3013 = 9
# Nilai awal angka2_3013 = 8
#
# Assignment Biasa (=)
# Hasil_3013 = 9
#
# Assignment Penambahan (+=)
# Hasil = 17
#
# Assignment Pengurangan (-=)
# Hasil = 1
#
# Assignment Perkalian (*=)
# Hasil = 72
#
# Assignment Pembagian (/=)
# Hasil = 1.125
#
# Assignment Pembagian Bulat (//=)
# Hasil = 1
#
# Assignment Sisa Bagi (%=)
# Hasil = 1
#
# Assignment Perpangkatan (**=)
# Hasil = 43046721

# %% [markdown]
# **Penjelasan :**
#
# 1. Membuat input angka
# angka1_3013 = int(input("Input angka-1: "))
#
# angka2_3013 = int(input("Input angka-2: "))
#
# Program meminta dua angka dari pengguna dan mengonversinya ke bentuk integer.
#
# 2. Assignment Biasa
# hasil_3013 = angka1_3013
#
# Operator = memberikan/memindahkan nilai dari angka1_3013 secara langsung ke variabel hasil_3013.
#
# 3. Assignment Penambahan
# hasil_3013 += angka2_3013
#
# Operator += menambahkan nilai hasil_3013 dengan angka2_3013 lalu menyimpan hasil terbarunya kembali ke hasil_3013 (ekuivalen dengan hasil_3013 = hasil_3013 + angka2_3013).
#
# 4. Assignment Pengurangan
# hasil_3013 -= angka2_3013
#
# Operator -= mengurangi nilai hasil_3013 dengan angka2_3013 lalu memperbarui variabel hasil_3013.
#
# 5. Assignment Perkalian
# hasil_3013 *= angka2_3013
#
# Operator *= mengalikan nilai hasil_3013 dengan angka2_3013.
#
# 6. Pengecekan Pembagian Assignment
# if angka2_3013 != 0:
#
# Memeriksa agar angka2_3013 tidak bernilai 0 agar tidak terjadi kesalahan pembagian.
#
# 7. Assignment Pembagian, Pembagian Bulat, dan Modulus
# hasil_3013 /= angka2_3013
#
# hasil_3013 //= angka2_3013
#
# hasil_3013 %= angka2_3013
#
# Operator /=, //=, dan %= masing-masing membagi, membagi bulat, dan mengambil sisa bagi dari hasil_3013 terhadap angka2_3013 secara langsung.
#
# 8. Assignment Perpangkatan
# hasil_3013 **= angka2_3013
#
# Operator **= memangkatkan nilai hasil_3013 dengan angka2_3013.

# %% [markdown]
# ### 2.2.5 Program Lainnya (Lainnya_2611533013.py)

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("======================================")
print("1. OPERATOR KEANGGOTAAN")
print("======================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_3013 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_3013 = [int(angka.strip()) for angka in input_data_3013.split(',')]

nilai_dicari_3013 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_3013 = nilai_dicari_3013 in data_3013
print("\nOperator keanggotaan IN")
print(nilai_dicari_3013,"in",data_3013,"=",hasil_3013)

# Operator not in
hasil_3013 = nilai_dicari_3013 not in data_3013
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_3013,"not in",data_3013,"=",hasil_3013)

print("======================================")
print("2. OPERATOR IDENTIAS")
print("======================================")

# objek1 menggunakan list dari input perngguna
object1_3013 = data_3013

# objek2 merujuk pada objek yang sama dengan objek1
object2_3013 = object1_3013

# objek3 memiliki isi sama, tetapi merupakan objek baru
object3_3013 = data_3013.copy()

print("object1 =",object1_3013)
print("object2 =",object2_3013)
print("object3 =",object3_3013)

# Operator is
hasil_3013 = object1_3013 is object2_3013
print("\nOperator identitas IS")
print("objek1 is objek2 =",hasil_3013)

# Operator is not
hasil_3013 = object1_3013 is not object2_3013
print("\nOperator identitas IS NOT")
print("objek1 is not objek2 =",hasil_3013)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =",object1_3013 is object3_3013)
print("objek1 == objek3 =",object1_3013 == object3_3013)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 2 in [1, 2] = True
#
# Operator keanggotaan NOT IN
# 2 not in [1, 2] = False
# ...
# 2. OPERATOR IDENTIAS
# ...
# object1 = [1, 2]
# object2 = [1, 2]
# object3 = [1, 2]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek2 = False
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. Membuat input data List
# data_3013 = [int(angka.strip()) for angka in input_data_3013.split(',')]
#
# Menerima string berisi beberapa angka yang dipisahkan koma, memotongnya dengan .split(','), dan mengonversi tiap angkanya menjadi integer di dalam List.
#
# 2. Operator Keanggotaan IN
# hasil_3013 = nilai_dicari_3013 in data_3013
#
# Operator in mengecek apakah nilai_dicari_3013 terdapat di dalam elemen list data_3013.
#
# 3. Operator Keanggotaan NOT IN
# hasil_3013 = nilai_dicari_3013 not in data_3013
#
# Operator not in mengecek apakah nilai_dicari_3013 tidak ada di dalam list data_3013.
#
# 4. Membuat Variabel Acuan Objek
# object2_3013 = object1_3013
#
# object3_3013 = data_3013.copy()
#
# object2_3013 merujuk ke memori yang sama dengan object1_3013, sedangkan object3_3013 menyalin isinya saja ke lokasi memori baru.
#
# 5. Operator Identitas IS
# hasil_3013 = object1_3013 is object2_3013
#
# Operator is mengecek apakah dua variabel berada di lokasi memori yang sama. Menghasilkan True untuk object1_3013 dan object2_3013.
#
# 6. Operator Identitas IS NOT
# hasil_3013 = object1_3013 is not object2_3013
#
# Operator is not mengecek apakah dua variabel berada di lokasi memori yang berbeda.
#
# 7. Perbandingan Nilai vs Lokasi Memori
# object1_3013 is object3_3013 menghasilkan False karena beda lokasi memori.
#
# object1_3013 == object3_3013 menghasilkan True karena isinya sama persis.

# %% [markdown]
# ### 2.2.6 Program Bitwise (Bitwise_2611533013.py)

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("======================================")
print("3. OPERATOR BITWISE")
print("======================================")

angka1_3013 = int(input("Masukkan angka bitwise-1: "))
angka2_3013 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =",angka1_3013,"| biner =",bin(angka1_3013))
print("angka1 =",angka2_3013,"| biner =",bin(angka2_3013))

# Bitwise AND
hasil_3013 = angka1_3013 & angka2_3013
print("\nBitwise AND (&)")
print(angka1_3013,"&",angka2_3013,hasil_3013)
print("Biner hasil =",bin(hasil_3013))
print("Biner hasil (8 bit) =",format(hasil_3013,"08b"))

# Bitwise OR
hasil_3013 = angka1_3013 | angka2_3013
print("\nBitwise OR (|)")
print(angka1_3013,"|",angka2_3013,hasil_3013)
print("Biner hasil =",bin(hasil_3013))
print("Biner hasil (8 bit) =",format(hasil_3013,"08b"))

# Bitwise XOR
hasil_3013 = angka1_3013 ^ angka2_3013
print("\nBitwise XOR (^)")
print(angka1_3013,"^",angka2_3013,hasil_3013)
print("Biner hasil =",bin(hasil_3013))
print("Biner hasil (8 bit) =",format(hasil_3013,"08b"))

# Bitwise NOT
hasil_3013 = ~angka1_3013
print("\nBitwise NOT (~)")
print(angka1_3013,"~",angka2_3013,hasil_3013)
print("Biner hasil =",bin(hasil_3013))
print("Biner hasil (8 bit) =",format(hasil_3013,"08b"))

# Bitwise geser kiri
jumlah_geser_3013 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_3013 = angka1_3013 << jumlah_geser_3013
print("\nBitwise geser kiri (<<)")
print(angka1_3013,"<<",jumlah_geser_3013,"=",hasil_3013)
print("Biner hasil =",bin(hasil_3013))
print("Biner hasil (8 bit) =",format(hasil_3013,"08b"))

# Bitwise geser kanan
hasil_3013 = angka1_3013 >> jumlah_geser_3013
print("\nBitwise geser kanan (>>)")
print(angka1_3013,">>",jumlah_geser_3013,"=",hasil_3013)
print("Biner hasil =",bin(hasil_3013))
print("Biner hasil (8 bit) =",format(hasil_3013,"08b"))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1 = 18 | biner = 0b10010
# angka1 = 12 | biner = 0b1100
#
# Bitwise AND (&)
# 18 & 12 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000
#
# Bitwise OR (|)
# 18 | 12 30
# Biner hasil = 0b11110
# Biner hasil (8 bit) = 00011110
#
# Bitwise XOR (^)
# 18 ^ 12 30
# Biner hasil = 0b11110
# Biner hasil (8 bit) = 00011110
#
# Bitwise NOT (~)
# 18 ~ 12 -19
# Biner hasil = -0b10011
# Biner hasil (8 bit) = -0010011
#
# Bitwise geser kiri (<<)
# 18 << 2 = 72
# Biner hasil = 0b1001000
# Biner hasil (8 bit) = 01001000
#
# Bitwise geser kanan (>>)
# 18 >> 2 = 4
# Biner hasil = 0b100
# Biner hasil (8 bit) = 00000100

# %% [markdown]
# **Penjelasan**:
#
# 1. Membuat input angka desimal & menampilkan biner
# bin(angka1_3013)
#
# Program meminta dua angka desimal, kemudian fungsi bin() mengonversi angka desimal tersebut menjadi format biner.
#
# 2. Bitwise AND (&)
# hasil_3013 = angka1_3013 & angka2_3013
#
# Operator & membandingkan bit demi bit dari kedua angka. Bit hasil akan bernilai 1 jika kedua bit bernilai 1.
#
# 3. Bitwise OR (|)
# hasil_3013 = angka1_3013 | angka2_3013
#
# Operator | membandingkan bit demi bit, bernilai 1 jika minimal salah satu bit bernilai 1.
#
# 4. Bitwise XOR (^)
# hasil_3013 = angka1_3013 ^ angka2_3013
#
# Operator ^ membandingkan bit demi bit, bernilai 1 jika bit-bitnya berbeda (satu bernilai 0 dan lainnya bernilai 1).
#
# 5. Bitwise NOT (~)
# hasil_3013 = ~angka1_3013
#
# Operator ~ membalikkan semua bit angka (sistem komplementer dua), menghasilkan rumus -(x + 1).
#
# 6. Bitwise Geser Kiri (<<)
# hasil_3013 = angka1_3013 << jumlah_geser_3013
#
# Operator << menggeser posisi bit ke kiri sebanyak jumlah_geser_3013 langkah (sama dengan mengalikan angka dengan 2n).
#
# 7. Bitwise Geser Kanan (>>)
# hasil_3013 = angka1_3013 >> jumlah_geser_3013
#
# Operator >> menggeser posisi bit ke kanan sebanyak jumlah_geser_3013 langkah (sama dengan membagi bulat angka dengan 2n).

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program Tugas3_2611533013

# %%
print("=== SISTEM TRANSAKSI TOKO ===")
nama_3013 = input("Masukkan Nama Pelanggan : ")
status_3013 = input("Masukkan Status Pelanggan (member/nonmember) : ")
total_3013 = int(input("Masukkan Total Belanja : "))
jumlah_3013 = int(input("Masukkan Jumlah Barang : "))
promo_3013 = input("Masukkan Kode Promo : ")

print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan       : {nama_3013}")
print(f"Status Pelanggan     : {status_3013}")
print(f"Total Belanja        : Rp{total_3013}")
print(f"Jumlah Barang        : {jumlah_3013}")
print(f"Kode Promo           : {promo_3013}")

kode_promo_3013 = ["HEMAT10", "HEMAT20", "HIDUPMAHASISWA", "HIDUPFTI"] #list kode promo

syarat_total_3013 = total_3013 >= 200000 # apakah memenuhi syarat belanja
syarat_jumlah_3013 = jumlah_3013 >= 3 # apakah memenuhi syarat barang
status_valid_3013 = status_3013 == "member" # apakah user member
promo_valid_3013 = promo_3013 in kode_promo_3013 # apakah kode promo ada dalam list

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000        : {syarat_total_3013}")
print(f"Jumlah Barang >= 3         : {syarat_jumlah_3013}")
print(f"Status Member              : {status_valid_3013}")
print(f"Kode Promo Tersedia        : {promo_valid_3013}")
print(f"Mendapatkan Diskon         : {syarat_jumlah_3013 or syarat_total_3013}")
print(f"Mendapatkan Promo          : {promo_valid_3013}")

diskon_3013 = 0.05

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                      : Rp{diskon_3013 * total_3013}")
print(f"Total Pembayaran            : Rp{total_3013 - total_3013 * diskon_3013}")
print(f"Rata-rata Harga Barang      : Rp{(total_3013 - total_3013 * diskon_3013)/jumlah_3013}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses              : ...")
print(f"Member Access               : {status_valid_3013}")
print(f"Promo Access                : {promo_valid_3013}")
print(f"Free Shipping Access        : ...")

kode_transaksi_3013 = int(status_valid_3013) << 0 | int(syarat_total_3013) << 1 | int(syarat_jumlah_3013) << 2 | int(promo_valid_3013) << 3
kode_referensi_3013 = int(status_valid_3013) << 0 | int(syarat_total_3013) << 1 | int(promo_valid_3013) << 3

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print(f"{format(int(status_valid_3013) << 0,'04b')} | {format(int(syarat_total_3013) << 1,'04b')} | {format(int(syarat_jumlah_3013) << 2,'04b')} | {format(int(promo_valid_3013) << 3,'04b')}")
print(f"Kode Biner   : {format(kode_transaksi_3013,'04b')}")
print(f"Kode Desimal : {kode_transaksi_3013}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(kode_transaksi_3013,'04b')} & {format(int(status_valid_3013) << 0,'04b')}")
print(f"Hasil Biner   : {format((kode_transaksi_3013) & int(status_valid_3013) << 0,'04b')}")
print(f"Hasil Desimal : {(kode_transaksi_3013) & int(status_valid_3013) << 0}")

print("Cek Promo")
print(f"{format(kode_transaksi_3013,'04b')} & {format(int(promo_valid_3013) << 3,'04b')}")
print(f"Hasil Biner   : {format((kode_transaksi_3013) & int(promo_valid_3013) << 3,'04b')}")
print(f"Hasil Desimal : {(kode_transaksi_3013) & int(promo_valid_3013) << 3}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(kode_transaksi_3013,'04b')}")
print(f"Kode Referensi : {format(kode_referensi_3013,'04b')}")
print(f"{format(kode_transaksi_3013,'04b')} ^ {format(kode_referensi_3013,'04b')}")
print(f"Hasil Biner   : {format((kode_transaksi_3013) ^ (kode_referensi_3013),'04b')}")
print(f"Hasil Desimal : {(kode_transaksi_3013) ^ (kode_referensi_3013)}")

print("\n=== Shift ===")
print(f"{format(kode_transaksi_3013,'04b')} << 1")
print(f"Hasil Biner   : {format((kode_transaksi_3013) << 1,'04b')}")
print(f"Hasil Desimal : {(kode_transaksi_3013) << 1}") 
print("=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA TRANSAKSI ===
# Nama Pelanggan       : Farras
# Status Pelanggan     : member
# Total Belanja        : Rp300000
# Jumlah Barang        : 6
# Kode Promo           : HEMAT20
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000        : True
# Jumlah Barang >= 3         : True
# Status Member              : True
# Kode Promo Tersedia        : True
# Mendapatkan Diskon         : True
# Mendapatkan Promo          : True
#
# === HASIL PERHITUNGAN ===
# Diskon                      : Rp15000.0
# Total Pembayaran            : Rp285000.0
# Rata-rata Harga Barang      : Rp47500.0
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses              : ...
# Member Access               : True
# Promo Access                : True
# Free Shipping Access        : ...
#
# === OPERASI BITWISE ===
# === Kode Status Transaksi ===
# 0001 | 0010 | 0100 | 1000
# Kode Biner   : 1111
# Kode Desimal : 15
#
# === Pemeriksaan Status ===
# Cek Member
# 1111 & 0001
# ...

# %% [markdown]
# **Penjelasan**:
#
# 1. Input Data Pelanggan dan Transaksi
# nama_3013 = input("Masukkan Nama Pelanggan : ")
# status_3013 = input("Masukkan Status Pelanggan (member/nonmember) : ")
# total_3013 = int(input("Masukkan Total Belanja : "))
# jumlah_3013 = int(input("Masukkan Jumlah Barang : "))
# promo_3013 = input("Masukkan Kode Promo : ")
#
# Program meminta masukan data transaksi dari pengguna. input() digunakan untuk teks (nama, status, promo), sedangkan int(input()) mengonversi input total belanja dan jumlah barang menjadi bilangan bulat.
#
# 2. Daftar Kode Promo (List) kode_promo_3013 = ["HEMAT10", "HEMAT20", "HIDUPMAHASISWA", "HIDUPFTI"]
# Membuat struktur data List yang menyimpan kumpulan kode promo resmi yang valid dan dapat digunakan di toko.
#
# 3. Validasi Syarat Transaksi (Operator Perbandingan & Keanggotaan)
# syarat_total_3013 = total_3013 >= 200000
# syarat_jumlah_3013 = jumlah_3013 >= 3
# status_valid_3013 = status_3013 == "member"
# promo_valid_3013 = promo_3013 in kode_promo_3013
#
# - Operator `>=` memeriksa apakah total belanja minimal Rp200.000 dan jumlah barang minimal 3 buah.
# - Operator `==` mengecek apakah status pelanggan bertuliskan `"member"`.
# - Operator keanggotaan `in` mengecek apakah kode promo yang diinput terdaftar di dalam list `kode_promo_3013`.
#
# 4. Evaluasi Kelayakan Diskon dan Promo (Operator Logika)
# syarat_jumlah_3013 or syarat_total_3013
# promo_valid_3013
#
# Operator logika or mengecek apakah pelanggan berhak mendapatkan diskon jika memenuhi minimal salah satu syarat (jumlah barang
#  ATAU total belanja
# ).
#
# 5. Perhitungan Diskon, Pembayaran, dan Rata-rata (Operator Aritmatika)
# diskon_3013 = 0.05 potongan_3013 = diskon_3013 * total_3013<br> total_bayar_3013 = total_3013 - potongan_3013<br> rata_rata_3013 = total_bayar_3013 / jumlah_3013`
#
# - Operator `*` menghitung nominal potongan diskon $5\%$.
# - Operator `-` mengurangi total belanja dengan nominal diskon untuk mendapatkan total akhir yang harus dibayar.
# - Operator `/`membagi total pembayaran akhir dengan jumlah barang untuk mencari rata-rata harga per barang.
#
# 6. Pembentukan Kode Status Transaksi (Operator Bitwise Shift & OR)
# kode_transaksi_3013 = int(status_valid_3013) << 0 | int(syarat_total_3013) << 1 | int(syarat_jumlah_3013) << 2 | int(promo_valid_3013) << 3
#
# Mengonversi nilai boolean (True/False) dari tiap syarat menjadi bit 1 atau 0, lalu menggeser posisinya menggunakan Shift Left (<<) ke posisi bit ke-0, ke-1, ke-2, dan ke-3. Hasilnya digabungkan menggunakan Bitwise OR (|) menjadi satu kode biner 4-bit yang merepresentasikan seluruh status transaksi.
#
# 7. Pemeriksaan Status Transaksi (Operator Bitwise AND)
#
# hasil_cek_member = (kode_transaksi_3013) & int(status_valid_3013) << 0 hasil_cek_promo = (kode_transaksi_3013) & int(promo_valid_3013) << 3
#
# Operator & (Bitwise AND) digunakan sebagai masking untuk mengecek atau memverifikasi apakah flag/bit tertentu (misalnya bit status member pada bit-0 atau status promo pada bit-3) bernilai aktif (1).
#
# 8. Perbandingan Status Transaksi dengan Referensi (Operator Bitwise XOR)
#
# kode_transaksi_3013 ^ kode_referensi_3013
#
# Operator ^ (Bitwise XOR) membandingkan kode transaksi aktual dengan kode referensi. Hasil bit akan bernilai 1 pada posisi bit yang mengalami perbedaan/selisih status antar kedua kode tersebut. 9. Pergeseran Kode Status (Operator Bitwise Shift Left)
#
# kode_transaksi_3013 << 1
#
# Operator << 1 menggeser seluruh bit pada kode_transaksi_3013 satu langkah ke kiri (ekuivalen dengan mengalikan nilai desimal kode tersebut dengan 2).

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# 1. Python menyediakan berbagai jenis operator yang mempermudah pemrosesan data, mulai dari kalkulasi numerik dasar (Aritmatika) hingga manipulasi bit secara langsung (Bitwise).
#
# 2. Penerapan pengkondisian sebelum operasi pembagian sangat penting untuk mencegah terjadinya kesalahan runtime akibat pembagian dengan nol (ZeroDivisionError).
#
# 3. Pemahaman perbedaan antara operator kesamaan nilai (==) dan identitas lokasi memori (is) membantu mencegah timbulnya bug saat memanipulasi objek majemuk seperti List.
#
# 4. Penggunaan operator assignment gabungan terbukti memperingkas penulisan sintaksis kode tanpa mengubah logika dasar operasi matematika.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1. Python Software Foundation. (2026). Python 3 Documentation. Python Software Foundation. https://docs.python.org/3/
#
# 2. Python Software Foundation. (2026). The Python Tutorial. Python Software Foundation. https://docs.python.org/3/tutorial/
#
# 3. W3Schools. (2026). Python Operators. W3Schools. https://www.w3schools.com/python/python_operators.asp
#
# 4. GeeksforGeeks. (2026). Python Operators. GeeksforGeeks. https://www.geeksforgeeks.org/python/python-operators/
